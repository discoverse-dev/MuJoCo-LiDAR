# %%
import mujoco
import numpy as np

np.set_printoptions(precision=3, suppress=True, linewidth=500)

mjcf_path = "/home/tatp/ws/gaussian_lidar/MuJoCo-LiDAR/models/demo.xml"

mj_model = mujoco.MjModel.from_xml_path(mjcf_path)
mj_data = mujoco.MjData(mj_model)
mujoco.mj_forward(mj_model, mj_data)

# 0: PLANE
# 2: SPHERE
# 3: CAPSULE
# 4: ELLIPSOID
# 5: CYLINDER
# 6: BOX
# 7: MESH

# %%
print(mj_model.geom_type)
print(mj_model.geom_aabb[1:,:])
# print(mj_model.geom_aabb[1:,:3])
# print(mj_model.geom_aabb[1:,3:])
# print(mj_model.geom_pos)
# print(mj_model.geom_quat)

# %%
mj_model.mesh_vert

# %%
mj_model.mesh_faceadr

# %%
mj_model.mesh_facenum

# %%
mj_model.mesh_face.shape
